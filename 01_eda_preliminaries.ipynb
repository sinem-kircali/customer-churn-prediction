# %%
import matplotlib.pyplot as plt
from bbplot import bijan
import pandas as pd
import numpy as np
from statsmodels.tsa.api import acf, graphics, pacf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from bbplot import bijan
import pandas as pd
import numpy as np
import itertools
import warnings
import random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('C:\\Users\\tunat\\OneDrive\\Masaüstü\\Copy of training_data.xlsx' , header=None)
data=data.iloc[5:,1:50]
data.columns=['ID','CAT1 SMOOTHED', 'CAT2 SMOOTHED', 'CAT3 SMOOTHED', 'CAT4 SMOOTHED', 'CAT5 SMOOTHED', 'CAT6 SMOOTHED', 'CAT7 SMOOTHED', 'CAT8 SMOOTHED', 'CAT9 SMOOTHED', 'CAT10 SMOOTHED', 'CAT11 SMOOTHED', 'CAT12 SMOOTHED', 'CAT13 SMOOTHED', 'CAT14 SMOOTHED', 'CAT15 SMOOTHED', 'CAT16 SMOOTHED', 'CAT17 SMOOTHED', 'CAT18 SMOOTHED', 'CAT19 SMOOTHED', 'CAT20 SMOOTHED', 'NUM1 SMOOTHED', 'NUM2 SMOOTHED','NUM3 SMOOTHED','NUM4 SMOOTHED','NUM5 SMOOTHED','NUM6 SMOOTHED','NUM7 SMOOTHED','NUM8 SMOOTHED','NUM9 SMOOTHED','NUM10 SMOOTHED','NUM11 SMOOTHED','NUM12 SMOOTHED','NUM13 SMOOTHED','NUM14 SMOOTHED','NUM15 SMOOTHED','NUM16 SMOOTHED','NUM17 SMOOTHED','NUM18 SMOOTHED','NUM19 SMOOTHED','NUM20 SMOOTHED','NUM21 SMOOTHED','NUM22 SMOOTHED','NUM23 SMOOTHED','NUM24 SMOOTHED','NUM25 SMOOTHED','NUM26 SMOOTHED','NUM27 SMOOTHED','TARGET SMOOTHED' ]
data
# Out:
#           ID CAT1 SMOOTHED CAT2 SMOOTHED CAT3 SMOOTHED CAT4 SMOOTHED  \
# 5      27758             7            12             7             7
# 6      93327             2             4             3             4
# 7       8635             7             8             4             1
# 8       8025             4             8             7             3
# 9      22309             2             8             4             1
# ...      ...           ...           ...           ...           ...
# 50000  18403             3             3             7             2
# 50001  91129             2             8             7             3
# 50002  62566             4             6             9             1
# 50003  23935             5             1             3             4
# 50004  91243             5             1             4             6
#
#       CAT5 SMOOTHED CAT6 SMOOTHED CAT7 SMOOTHED CAT8 SMOOTHED CAT9 SMOOTHED  \
# ...

# %%
data['ID']= data['ID'].astype(float)
data['CAT1 SMOOTHED']= data['CAT1 SMOOTHED'].astype(float)
data['CAT2 SMOOTHED']= data['CAT2 SMOOTHED'].astype(float)
data['CAT3 SMOOTHED']= data['CAT3 SMOOTHED'].astype(float)
data['CAT4 SMOOTHED']= data['CAT4 SMOOTHED'].astype(float)
data['CAT5 SMOOTHED']= data['CAT5 SMOOTHED'].astype(float)
data['CAT6 SMOOTHED']= data['CAT6 SMOOTHED'].astype(float)
data['CAT7 SMOOTHED']= data['CAT8 SMOOTHED'].astype(float)
data['CAT8 SMOOTHED']= data['CAT9 SMOOTHED'].astype(float)
data['CAT9 SMOOTHED']= data['CAT10 SMOOTHED'].astype(float)
data['CAT10 SMOOTHED']= data['CAT11 SMOOTHED'].astype(float)
data['CAT11 SMOOTHED']= data['CAT12 SMOOTHED'].astype(float)
data['CAT12 SMOOTHED']= data['CAT13 SMOOTHED'].astype(float)
data['CAT13 SMOOTHED']= data['CAT14 SMOOTHED'].astype(float)
data['CAT14 SMOOTHED']= data['CAT15 SMOOTHED'].astype(float)
data['CAT15 SMOOTHED']= data['CAT16 SMOOTHED'].astype(float)
data['CAT16 SMOOTHED']= data['CAT17 SMOOTHED'].astype(float)
data['CAT17 SMOOTHED']= data['CAT18 SMOOTHED'].astype(float)
data['CAT18 SMOOTHED']= data['CAT19 SMOOTHED'].astype(float)
data['CAT19 SMOOTHED']= data['CAT20 SMOOTHED'].astype(float)
data['CAT20 SMOOTHED']= data['CAT1 SMOOTHED'].astype(float)
data['NUM1 SMOOTHED']= data['NUM1 SMOOTHED'].astype(float)
data['NUM2 SMOOTHED']= data['NUM2 SMOOTHED'].astype(float)
data['NUM3 SMOOTHED']= data['NUM3 SMOOTHED'].astype(float)
data['NUM4 SMOOTHED']= data['NUM4 SMOOTHED'].astype(float)
data['NUM5 SMOOTHED']= data['NUM5 SMOOTHED'].astype(float)
data['NUM6 SMOOTHED']= data['NUM6 SMOOTHED'].astype(float)
data['NUM7 SMOOTHED']= data['NUM7 SMOOTHED'].astype(float)
data['NUM8 SMOOTHED']= data['NUM8 SMOOTHED'].astype(float)
data['NUM9 SMOOTHED']= data['NUM9 SMOOTHED'].astype(float)
data['NUM10 SMOOTHED']= data['NUM10 SMOOTHED'].astype(float)
data['NUM11 SMOOTHED']= data['NUM11 SMOOTHED'].astype(float)
data['NUM12 SMOOTHED']= data['NUM12 SMOOTHED'].astype(float)
data['NUM13 SMOOTHED']= data['NUM13 SMOOTHED'].astype(float)
data['NUM14 SMOOTHED']= data['NUM14 SMOOTHED'].astype(float)
data['NUM15 SMOOTHED']= data['NUM15 SMOOTHED'].astype(float)
data['NUM16 SMOOTHED']= data['NUM16 SMOOTHED'].astype(float)
data['NUM17 SMOOTHED']= data['NUM17 SMOOTHED'].astype(float)
data['NUM18 SMOOTHED']= data['NUM18 SMOOTHED'].astype(float)
data['NUM19 SMOOTHED']= data['NUM19 SMOOTHED'].astype(float)
data['NUM20 SMOOTHED']= data['NUM20 SMOOTHED'].astype(float)
data['NUM21 SMOOTHED']= data['NUM21 SMOOTHED'].astype(float)
data['NUM22 SMOOTHED']= data['NUM22 SMOOTHED'].astype(float)
data['NUM23 SMOOTHED']= data['NUM23 SMOOTHED'].astype(float)
data['NUM24 SMOOTHED']= data['NUM24 SMOOTHED'].astype(float)
data['NUM25 SMOOTHED']= data['NUM25 SMOOTHED'].astype(float)
data['NUM26 SMOOTHED']= data['NUM26 SMOOTHED'].astype(float)
data['NUM27 SMOOTHED']= data['NUM27 SMOOTHED'].astype(float)
data['TARGET SMOOTHED']= data['TARGET SMOOTHED'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-11a8008ac0d0> in <module>
# ----> 1 data['ID']= data['ID'].astype(float)
#       2 data['CAT1 SMOOTHED']= data['CAT1 SMOOTHED'].astype(float)
#       3 data['CAT2 SMOOTHED']= data['CAT2 SMOOTHED'].astype(float)
#       4 data['CAT3 SMOOTHED']= data['CAT3 SMOOTHED'].astype(float)
#       5 data['CAT4 SMOOTHED']= data['CAT4 SMOOTHED'].astype(float)
#
# NameError: name 'data' is not defined

# %%
data.corr()
# Out:
#                        ID  CAT1 SMOOTHED  CAT2 SMOOTHED  CAT3 SMOOTHED  \
# ID               1.000000      -0.024727       0.008413      -0.038990
# CAT1 SMOOTHED   -0.024727       1.000000      -0.360154       0.059327
# CAT2 SMOOTHED    0.008413      -0.360154       1.000000       0.039606
# CAT3 SMOOTHED   -0.038990       0.059327       0.039606       1.000000
# CAT4 SMOOTHED   -0.022344       0.171469      -0.059271       0.051163
# CAT5 SMOOTHED    0.031316       0.005125       0.012579      -0.026859
# CAT6 SMOOTHED    0.003670      -0.050152       0.334457      -0.017892
# CAT7 SMOOTHED   -0.067642       0.081196       0.034049       0.119588
# CAT8 SMOOTHED   -0.023713       0.134083      -0.004072       0.087954
# CAT9 SMOOTHED    0.006888      -0.328966       0.805824       0.022643
# CAT10 SMOOTHED  -0.017238       0.846023      -0.370326       0.043678
# CAT11 SMOOTHED   0.008146      -0.024904      -0.314077      -0.077898
# ...

# %%
plt.figure(figsize=(40, 25))
heatmap=sns.heatmap(data.corr(), annot=True,yticklabels=data.columns,xticklabels=data.columns)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':24}, pad=12);

# %%
plt.hist(data['CAT1 SMOOTHED'])
plt.title('CAT1')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT2 SMOOTHED'])
plt.title('CAT2')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT3 SMOOTHED'])
plt.title('CAT3')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT4 SMOOTHED'])
plt.title('CAT4')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT5 SMOOTHED'])
plt.title('CAT5')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT6 SMOOTHED'])
plt.title('CAT6')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT2 SMOOTHED'])
plt.title('CAT1')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT6 SMOOTHED'])
plt.title('CAT6')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT7 SMOOTHED'])
plt.title('CAT7')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT8 SMOOTHED'])
plt.title('CAT8')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT9 SMOOTHED'])
plt.title('CAT9')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT10 SMOOTHED'])
plt.title('CAT10')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT11 SMOOTHED'])
plt.title('CAT11')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT12 SMOOTHED'])
plt.title('CAT12')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT13 SMOOTHED'])
plt.title('CAT13')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT14 SMOOTHED'])
plt.title('CAT14')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT15 SMOOTHED'])
plt.title('CAT15')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT16 SMOOTHED'])
plt.title('CAT16')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT17 SMOOTHED'])
plt.title('CAT17')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT18 SMOOTHED'])
plt.title('CAT18')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT19 SMOOTHED'])
plt.title('CAT19')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['CAT20 SMOOTHED'])
plt.title('CAT20')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM1 SMOOTHED'])
plt.title('NUM1')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM2 SMOOTHED'])
plt.title('NUM2')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM3 SMOOTHED'])
plt.title('NUM3')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM4 SMOOTHED'])
plt.title('NUM4')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM5 SMOOTHED'])
plt.title('NUM5')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM6 SMOOTHED'])
plt.title('NUM6')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM7 SMOOTHED'])
plt.title('NUM7')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM8 SMOOTHED'])
plt.title('NUM8')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM9 SMOOTHED'])
plt.title('NUM9')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM10 SMOOTHED'])
plt.title('NUM10')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM11 SMOOTHED'])
plt.title('NUM11')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM12 SMOOTHED'])
plt.title('NUM12')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM13 SMOOTHED'])
plt.title('NUM13')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM14 SMOOTHED'])
plt.title('NUM14')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM15 SMOOTHED'])
plt.title('NUM15')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM16 SMOOTHED'])
plt.title('NUM16')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM17 SMOOTHED'])
plt.title('NUM17')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM18 SMOOTHED'])
plt.title('NUM18')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM19 SMOOTHED'])
plt.title('NUM19')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM20 SMOOTHED'])
plt.title('NUM20')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM21 SMOOTHED'])
plt.title('NUM21')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM22 SMOOTHED'])
plt.title('NUM22')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM23 SMOOTHED'])
plt.title('NUM23')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM24 SMOOTHED'])
plt.title('NUM24')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM25 SMOOTHED'])
plt.title('NUM25')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM26 SMOOTHED'])
plt.title('NUM26')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['NUM27 SMOOTHED'])
plt.title('NUM27')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

plt.hist(data['TARGET SMOOTHED'])
plt.title('TARET')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT1 SMOOTHED'])
plt.title('CAT1')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT2 SMOOTHED'])
plt.title('CAT2')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT3 SMOOTHED'])
plt.title('CAT3')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT4 SMOOTHED'])
plt.title('CAT4')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT5 SMOOTHED'])
plt.title('CAT5')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT6 SMOOTHED'])
plt.title('CAT6')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT7 SMOOTHED'])
plt.title('CAT7')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT8 SMOOTHED'])
plt.title('CAT8')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT9 SMOOTHED'])
plt.title('CAT9')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT10 SMOOTHED'])
plt.title('CAT10')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT11 SMOOTHED'])
plt.title('CAT11')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT12 SMOOTHED'])
plt.title('CAT12')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT13 SMOOTHED'])
plt.title('CAT13')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT14 SMOOTHED'])
plt.title('CAT14')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT15 SMOOTHED'])
plt.title('CAT15')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT16 SMOOTHED'])
plt.title('CAT16')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT16 SMOOTHED'])
plt.title('CAT16')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT17 SMOOTHED'])
plt.title('CAT17')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT18 SMOOTHED'])
plt.title('CAT18')

plt.figure(figsize=(10, 5))
plt.boxplot(data['CAT19 SMOOTHED'])
plt.title('CAT19')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM1 SMOOTHED'])
plt.title('NUM1')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM2 SMOOTHED'])
plt.title('NUM2')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM3 SMOOTHED'])
plt.title('NUM3')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM4 SMOOTHED'])
plt.title('NUM4')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM5 SMOOTHED'])
plt.title('NUM5')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM6 SMOOTHED'])
plt.title('NUM6')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM7 SMOOTHED'])
plt.title('NUM7')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM8 SMOOTHED'])
plt.title('NUM8')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM9 SMOOTHED'])
plt.title('NUM9')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM10 SMOOTHED'])
plt.title('NUM10')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM11 SMOOTHED'])
plt.title('NUM11')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM12 SMOOTHED'])
plt.title('NUM12')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM13 SMOOTHED'])
plt.title('NUM13')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM14 SMOOTHED'])
plt.title('NUM14')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM15 SMOOTHED'])
plt.title('NUM15')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM16 SMOOTHED'])
plt.title('NUM16')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM17 SMOOTHED'])
plt.title('NUM17')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM18 SMOOTHED'])
plt.title('NUM18')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM19 SMOOTHED'])
plt.title('NUM19')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM20 SMOOTHED'])
plt.title('NUM20')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM21 SMOOTHED'])
plt.title('NUM21')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM22 SMOOTHED'])
plt.title('NUM22')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM23 SMOOTHED'])
plt.title('NUM23')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM24 SMOOTHED'])
plt.title('NUM24')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM25 SMOOTHED'])
plt.title('NUM25')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM26 SMOOTHED'])
plt.title('NUM26')

plt.figure(figsize=(10, 5))
plt.boxplot(data['NUM27 SMOOTHED'])
plt.title('NUM27')

plt.figure(figsize=(10, 5))
plt.boxplot(data['TARGET SMOOTHED'])
plt.title('TARGET')
# Out:
# <ipython-input-8-d7deaea09ab1>:81: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 5))
# Text(0.5, 1.0, 'TARGET')

# %%
data_cat=pd.read_excel('C:\\Users\\tunat\\OneDrive\\Masaüstü\\Copy of training_data.xlsx' , header=None)
data_cat=data_cat.iloc[5:,2:22]
data_cat.columns=['CAT1 SMOOTHED', 'CAT2 SMOOTHED', 'CAT3 SMOOTHED', 'CAT4 SMOOTHED', 'CAT5 SMOOTHED', 'CAT6 SMOOTHED', 'CAT7 SMOOTHED', 'CAT8 SMOOTHED', 'CAT9 SMOOTHED', 'CAT10 SMOOTHED', 'CAT11 SMOOTHED', 'CAT12 SMOOTHED', 'CAT13 SMOOTHED', 'CAT14 SMOOTHED', 'CAT15 SMOOTHED', 'CAT16 SMOOTHED', 'CAT17 SMOOTHED', 'CAT18 SMOOTHED', 'CAT19 SMOOTHED', 'CAT20 SMOOTHED']
data_cat
# Out:
#       CAT1 SMOOTHED CAT2 SMOOTHED CAT3 SMOOTHED CAT4 SMOOTHED CAT5 SMOOTHED  \
# 5                 7            12             7             7            11
# 6                 2             4             3             4            33
# 7                 7             8             4             1            67
# 8                 4             8             7             3            52
# 9                 2             8             4             1            40
# ...             ...           ...           ...           ...           ...
# 50000             3             3             7             2             7
# 50001             2             8             7             3            78
# 50002             4             6             9             1             7
# 50003             5             1             3             4            40
# 50004             5             1             4             6            73
#
# ...

# %%
data_num=pd.read_excel('C:\\Users\\tunat\\OneDrive\\Masaüstü\\Copy of training_data.xlsx' , header=None)
data_num=data_num.iloc[5:,22:50]
data_num.columns=['NUM1 SMOOTHED', 'NUM2 SMOOTHED','NUM3 SMOOTHED','NUM4 SMOOTHED','NUM5 SMOOTHED','NUM6 SMOOTHED','NUM7 SMOOTHED','NUM8 SMOOTHED','NUM9 SMOOTHED','NUM10 SMOOTHED','NUM11 SMOOTHED','NUM12 SMOOTHED','NUM13 SMOOTHED','NUM14 SMOOTHED','NUM15 SMOOTHED','NUM16 SMOOTHED','NUM17 SMOOTHED','NUM18 SMOOTHED','NUM19 SMOOTHED','NUM20 SMOOTHED','NUM21 SMOOTHED','NUM22 SMOOTHED','NUM23 SMOOTHED','NUM24 SMOOTHED','NUM25 SMOOTHED','NUM26 SMOOTHED','NUM27 SMOOTHED','TARGET SMOOTHED' ]
data_num
# Out:
#       NUM1 SMOOTHED NUM2 SMOOTHED NUM3 SMOOTHED NUM4 SMOOTHED NUM5 SMOOTHED  \
# 5                 1             0           0.5             0             0
# 6                 2             1      0.714286             0             5
# 7                 1             0             1             0             1
# 8                 1             0      0.777778             0             1
# 9                 1             1      0.816955             0             1
# ...             ...           ...           ...           ...           ...
# 50000             1             0             1             0             2
# 50001             1             0             1             0             0
# 50002             2       0.80962             1             0             0
# 50003             2             0             1             0             0
# 50004             1             0      0.816955             0             0
#
# ...

# %%
data_num['NUM1 SMOOTHED']= data_num['NUM1 SMOOTHED'].astype(float)
data_num['NUM2 SMOOTHED']= data_num['NUM2 SMOOTHED'].astype(float)
data_num['NUM3 SMOOTHED']= data_num['NUM3 SMOOTHED'].astype(float)
data_num['NUM4 SMOOTHED']= data_num['NUM4 SMOOTHED'].astype(float)
data_num['NUM5 SMOOTHED']= data_num['NUM5 SMOOTHED'].astype(float)
data_num['NUM6 SMOOTHED']= data_num['NUM6 SMOOTHED'].astype(float)
data_num['NUM7 SMOOTHED']= data_num['NUM7 SMOOTHED'].astype(float)
data_num['NUM8 SMOOTHED']= data_num['NUM8 SMOOTHED'].astype(float)
data_num['NUM9 SMOOTHED']= data_num['NUM9 SMOOTHED'].astype(float)
data_num['NUM10 SMOOTHED']= data_num['NUM10 SMOOTHED'].astype(float)
data_num['NUM11 SMOOTHED']= data_num['NUM11 SMOOTHED'].astype(float)
data_num['NUM12 SMOOTHED']= data_num['NUM12 SMOOTHED'].astype(float)
data_num['NUM13 SMOOTHED']= data_num['NUM13 SMOOTHED'].astype(float)
data_num['NUM14 SMOOTHED']= data_num['NUM14 SMOOTHED'].astype(float)
data_num['NUM15 SMOOTHED']= data_num['NUM15 SMOOTHED'].astype(float)
data_num['NUM16 SMOOTHED']= data_num['NUM16 SMOOTHED'].astype(float)
data_num['NUM17 SMOOTHED']= data_num['NUM17 SMOOTHED'].astype(float)
data_num['NUM18 SMOOTHED']= data_num['NUM18 SMOOTHED'].astype(float)
data_num['NUM19 SMOOTHED']= data_num['NUM19 SMOOTHED'].astype(float)
data_num['NUM20 SMOOTHED']= data_num['NUM20 SMOOTHED'].astype(float)
data_num['NUM21 SMOOTHED']= data_num['NUM21 SMOOTHED'].astype(float)
data_num['NUM22 SMOOTHED']= data_num['NUM22 SMOOTHED'].astype(float)
data_num['NUM23 SMOOTHED']= data_num['NUM23 SMOOTHED'].astype(float)
data_num['NUM24 SMOOTHED']= data_num['NUM24 SMOOTHED'].astype(float)
data_num['NUM25 SMOOTHED']= data_num['NUM25 SMOOTHED'].astype(float)
data_num['NUM26 SMOOTHED']= data_num['NUM26 SMOOTHED'].astype(float)
data_num['NUM27 SMOOTHED']= data_num['NUM27 SMOOTHED'].astype(float)
data_num['TARGET SMOOTHED']= data_num['TARGET SMOOTHED'].astype(float)

# %%
plt.figure(figsize=(40, 25))
heatmap=sns.heatmap(data_num.corr(), annot=True,yticklabels=data_num.columns,xticklabels=data_num.columns)
heatmap.set_title('Correlation Heatmap Numeric', fontdict={'fontsize':24}, pad=12);

# %%
result = data_cat.dtypes
print(result)
# Out:
# CAT1 SMOOTHED     object
# CAT2 SMOOTHED     object
# CAT3 SMOOTHED     object
# CAT4 SMOOTHED     object
# CAT5 SMOOTHED     object
# CAT6 SMOOTHED     object
# CAT7 SMOOTHED     object
# CAT8 SMOOTHED     object
# CAT9 SMOOTHED     object
# CAT10 SMOOTHED    object
# CAT11 SMOOTHED    object
# CAT12 SMOOTHED    object
# CAT13 SMOOTHED    object
# CAT14 SMOOTHED    object
# CAT15 SMOOTHED    object
# CAT16 SMOOTHED    object
# CAT17 SMOOTHED    object
# CAT18 SMOOTHED    object
# CAT19 SMOOTHED    object
# CAT20 SMOOTHED    object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e3563cf11088> in <module>
# ----> 1 plt.scatter(data_num)
#       2 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'
